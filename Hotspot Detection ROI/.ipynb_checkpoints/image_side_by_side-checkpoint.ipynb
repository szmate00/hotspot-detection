# %%
import matplotlib.patches as patches
from matplotlib import pyplot as plt
import numpy as np
import h5py
import cv2


# filename
File = 'AEQ31_edi_20181002_049_161934'


with h5py.File(f'C:/TDK/adatok/{File}.h5', 'r') as hdf:
    roip = hdf.get('ROIP')
    roip1 = roip.get('ROIP1')
    roip1_data = roip1.get('ROIP1Data')
    roip_avg = roip1.get('ROIP1Average')
        
    image0 = np.array(roip1_data[:1024, :1280, 215])
    image = image0
        
    # using median filter
    blur = cv2.medianBlur(image, 3)
        
    # binarization
    thresh = cv2.threshold(blur, 3600, 4095, cv2.THRESH_BINARY)[1]
        
    # plotting the original and the manipulated image
    plt.figure(figsize=(16,16))
    
    plt.subplot(1, 2, 1)
    plt.imshow(image0, vmin=0, vmax=4095, cmap='gray')
    plt.title('Original image')
    plt.axis('off')
    
    ax = plt.gca()
    rect1 = patches.Rectangle((465,90),105,150,linewidth=1,edgecolor='r',facecolor='none', label='size of ROI1: 85x130')
    ax.add_patch(rect1)
    
    rect2 = patches.Rectangle((440,65),155,200,linewidth=1,edgecolor='g',facecolor='none', label='size of ROI2: 135x180')
    ax.add_patch(rect2)
    
    plt.legend(loc='upper right', fontsize=12)
    

    plt.subplot(1, 2, 2)
    plt.imshow(thresh, vmin=0, vmax=4095, cmap='gray')
    plt.title('Manipulated image')
    plt.axis('off')
    
    ax = plt.gca()
    rect1 = patches.Rectangle((465,90),105,150,linewidth=1,edgecolor='r',facecolor='none', label='size of ROI1: 85x130')
    ax.add_patch(rect1)
    
    rect2 = patches.Rectangle((440,65),155,200,linewidth=1,edgecolor='g',facecolor='none', label='size of ROI2: 135x180')
    ax.add_patch(rect2)
    
    plt.legend(loc='upper right', fontsize=12)
    
    
    plt.tight_layout()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\cbook\__init__.py in index_of(y)
#    1673     try:
# -> 1674         return y.index.values, y.values
#    1675     except AttributeError:
#
# AttributeError: 'Dataset' object has no attribute 'index'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3b8be8161710> in <module>
# ----> 1 plt.plot(roip_avg)
#
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     387             y = _check_1d(tup[-1])
#     388         else:
# --> 389             x, y = index_of(tup[-1])
#     390
#     391         x, y = self._xy_from_xy(x, y)
#
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\cbook\__init__.py in index_of(y)
#    1674         return y.index.values, y.values
#    1675     except AttributeError:
# -> 1676         y = _check_1d(y)
#    1677         return np.arange(y.shape[0], dtype=float), y
#    1678
#
# ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1396     dimension; leaves everything else untouched.
#    1397     '''
# -> 1398     if not hasattr(x, 'shape') or len(x.shape) < 1:
#    1399         return np.atleast_1d(x)
#    1400     else:
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~\anaconda3\envs\myenv\lib\site-packages\h5py\_hl\dataset.py in shape(self)
#     223     def shape(self):
#     224         """Numpy-style shape tuple giving dataset dimensions"""
# --> 225         return self.id.shape
#     226     @shape.setter
#     227     @with_phil
#
# h5py\h5d.pyx in h5py.h5d.DatasetID.shape.__get__()
#
# h5py\h5d.pyx in h5py.h5d.DatasetID.shape.__get__()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5d.pyx in h5py.h5d.DatasetID.get_space()
#
# ValueError: Not a dataset (not a dataset)
